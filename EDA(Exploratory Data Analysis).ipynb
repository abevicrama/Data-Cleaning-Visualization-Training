# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("world_population_data.csv")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df
# Out:
#      rank cca3                           country      continent  \
# 0       1  IND                             India           Asia
# 1       2  CHN                             China           Asia
# 2       3  USA                     United States  North America
# 3       4  IDN                         Indonesia           Asia
# 4       5  PAK                          Pakistan           Asia
# 5       6  NGA                           Nigeria         Africa
# 6       7  BRA                            Brazil  South America
# 7       8  BGD                        Bangladesh           Asia
# 8       9  RUS                            Russia         Europe
# 9      10  MEX                            Mexico  North America
# 10     11  ETH                          Ethiopia         Africa
# 11     12  JPN                             Japan           Asia
# 12     13  PHL                       Philippines           Asia
# 13     14  EGY                             Egypt         Africa
# ...

# %%
df[['2023 population','2022 population','2020 population','2015 population','2010 population','2000 population','1990 population','1980 population','1970 population']] = df[['2023 population','2022 population','2020 population','2015 population','2010 population','2000 population','1990 population','1980 population','1970 population']].astype('float')

# %%
df
# Out:
#      rank cca3                           country      continent  \
# 0       1  IND                             India           Asia
# 1       2  CHN                             China           Asia
# 2       3  USA                     United States  North America
# 3       4  IDN                         Indonesia           Asia
# 4       5  PAK                          Pakistan           Asia
# 5       6  NGA                           Nigeria         Africa
# 6       7  BRA                            Brazil  South America
# 7       8  BGD                        Bangladesh           Asia
# 8       9  RUS                            Russia         Europe
# 9      10  MEX                            Mexico  North America
# 10     11  ETH                          Ethiopia         Africa
# 11     12  JPN                             Japan           Asia
# 12     13  PHL                       Philippines           Asia
# 13     14  EGY                             Egypt         Africa
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df
# Out:
#      rank cca3                           country      continent  \
# 0       1  IND                             India           Asia
# 1       2  CHN                             China           Asia
# 2       3  USA                     United States  North America
# 3       4  IDN                         Indonesia           Asia
# 4       5  PAK                          Pakistan           Asia
# 5       6  NGA                           Nigeria         Africa
# 6       7  BRA                            Brazil  South America
# 7       8  BGD                        Bangladesh           Asia
# 8       9  RUS                            Russia         Europe
# 9      10  MEX                            Mexico  North America
# 10     11  ETH                          Ethiopia         Africa
# 11     12  JPN                             Japan           Asia
# 12     13  PHL                       Philippines           Asia
# 13     14  EGY                             Egypt         Africa
# ...

# %%
df['2023 population']=df['2023 population'].drop(index = 0)

# %%
df
# Out:
#      rank cca3                           country      continent  \
# 0       1  IND                             India           Asia
# 1       2  CHN                             China           Asia
# 2       3  USA                     United States  North America
# 3       4  IDN                         Indonesia           Asia
# 4       5  PAK                          Pakistan           Asia
# 5       6  NGA                           Nigeria         Africa
# 6       7  BRA                            Brazil  South America
# 7       8  BGD                        Bangladesh           Asia
# 8       9  RUS                            Russia         Europe
# 9      10  MEX                            Mexico  North America
# 10     11  ETH                          Ethiopia         Africa
# 11     12  JPN                             Japan           Asia
# 12     13  PHL                       Philippines           Asia
# 13     14  EGY                             Egypt         Africa
# ...

# %%
df.describe()
# Out:
#         rank  2023 population  2022 population  2020 population  \
# count 234.00           233.00           234.00           234.00
# mean  117.50      28390505.27      34074414.71      33501070.95
# std    67.69     102671125.10     136766424.80     135589876.92
# min     1.00           518.00           510.00           520.00
# 25%    59.25        412623.00        419738.50        415284.50
# 50%   117.50       5545475.00       5559944.50       5493074.50
# 75%   175.75      23227014.00      22476504.75      21447979.50
# max   234.00    1425671352.00    1425887337.00    1424929781.00
#
#        2015 population  2010 population  2000 population  1990 population  \
# count           234.00           234.00           234.00           234.00
# mean       31729956.24      29845235.04      26269468.82      22710220.79
# std       130404992.75     124218487.63     111698206.72      97832173.35
# min             564.00           596.00           651.00           700.00
# ...

# %%
df.isnull().sum()
# Out:
# rank                0
# cca3                0
# country             0
# continent           0
# 2023 population     1
# 2022 population     0
# 2020 population     0
# 2015 population     0
# 2010 population     0
# 2000 population     0
# 1990 population     0
# 1980 population     0
# 1970 population     0
# area (km²)          0
# density (km²)       0
# growth rate         0
# world percentage    0
# dtype: int64

# %%
df.nunique()
# Out:
# rank                234
# cca3                234
# country             234
# continent             6
# 2023 population     233
# 2022 population     234
# 2020 population     234
# 2015 population     234
# 2010 population     234
# 2000 population     234
# 1990 population     234
# 1980 population     234
# 1970 population     234
# area (km²)          232
# density (km²)       167
# growth rate         176
# world percentage     73
# dtype: int64

# %%
df.sort_values(by="rank",ascending=True).head(10)
# Out:
#    rank cca3        country      continent  2023 population  2022 population  \
# 0     1  IND          India           Asia              NaN    1417173173.00
# 1     2  CHN          China           Asia    1425671352.00    1425887337.00
# 2     3  USA  United States  North America     339996563.00     338289857.00
# 3     4  IDN      Indonesia           Asia     277534122.00     275501339.00
# 4     5  PAK       Pakistan           Asia     240485658.00     235824862.00
# 5     6  NGA        Nigeria         Africa     223804632.00     218541212.00
# 6     7  BRA         Brazil  South America     216422446.00     215313498.00
# 7     8  BGD     Bangladesh           Asia     172954319.00     171186372.00
# 8     9  RUS         Russia         Europe     144444359.00     144713314.00
# 9    10  MEX         Mexico  North America     128455567.00     127504125.00
#
#    2020 population  2015 population  2010 population  2000 population  \
# ...

# %%
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()

print(correlation_matrix)
# Out:
#                  rank  2023 population  2022 population  2020 population  \
# rank             1.00            -0.38            -0.36            -0.36
# 2023 population -0.38             1.00             1.00             1.00
# 2022 population -0.36             1.00             1.00             1.00
# 2020 population -0.36             1.00             1.00             1.00
# 2015 population -0.35             1.00             1.00             1.00
# 2010 population -0.35             1.00             1.00             1.00
# 2000 population -0.34             0.99             0.99             1.00
# 1990 population -0.34             0.99             0.99             0.99
# 1980 population -0.33             0.99             0.98             0.98
# 1970 population -0.33             0.98             0.97             0.98
# area (km²)      -0.38             0.52             0.45             0.45
# density (km²)    0.13            -0.04            -0.03            -0.03
#
# ...

# %%
sns.heatmap(correlation_matrix, annot = True)
plt.rcParams['figure.figsize'] = (20,7)
plt.show()

# %%
df.groupby('continent')

# %%
print(df.groupby('continent').mean(numeric_only=True))
# Out:
#                 rank  2023 population  2022 population  2020 population  \
# continent
# Africa         91.88      25622394.00      25030367.25      23871435.26
# Asia           77.56      67820243.37      94427665.48      93261730.70
# Europe        124.78      14837383.94      14862950.76      14915843.92
# North America 160.88      15103884.22      15007403.40      14855914.82
# Oceania       188.57       1981555.17       1958198.00       1910148.96
# South America  97.79      31408500.64      31201186.29      30823574.50
#
#                2015 population  2010 population  2000 population  \
# continent
# Africa             21071972.67      18512773.19      14367474.25
# Asia               89165003.64      84400826.54      74701792.08
# Europe             14830712.16      14712278.72      14521868.46
# North America      14259596.25      13568016.28      12151739.60
# Oceania             1756664.48       1613163.65       1357512.09
# ...

# %%
df[df['continent'].str.contains('Asia')]
# Out:
#      rank cca3               country continent  2023 population  \
# 0       1  IND                 India      Asia              NaN
# 1       2  CHN                 China      Asia    1425671352.00
# 3       4  IDN             Indonesia      Asia     277534122.00
# 4       5  PAK              Pakistan      Asia     240485658.00
# 7       8  BGD            Bangladesh      Asia     172954319.00
# 11     12  JPN                 Japan      Asia     123294513.00
# 12     13  PHL           Philippines      Asia     117337368.00
# 15     16  VNM               Vietnam      Asia      98858950.00
# 16     17  IRN                  Iran      Asia      89172767.00
# 17     18  TUR                Turkey      Asia      85816199.00
# 19     20  THA              Thailand      Asia      71801279.00
# 26     27  MMR               Myanmar      Asia      54577997.00
# 28     29  KOR           South Korea      Asia      51784059.00
# 34     35  IRQ                  Iraq      Asia      45504560.00
# ...

# %%
df.columns
# Out:
# Index(['rank', 'cca3', 'country', 'continent', '2023 population',
#        '2022 population', '2020 population', '2015 population',
#        '2010 population', '2000 population', '1990 population',
#        '1980 population', '1970 population', 'area (km²)', 'density (km²)',
#        'growth rate', 'world percentage'],
#       dtype='object')

# %%
#df2 =df.groupby('continent')[['2023 population','2022 population', '2020 population', '2015 population','2010 population', '2000 population', '1990 population','1980 population', '1970 population']].mean(numeric_only=True).sort_values(by="2022 population", ascending = False)
df2 =df.groupby('continent')[df.columns[4:13]].mean(numeric_only=True).sort_values(by="2022 population", ascending = False)

# %%
df2.plot()
# Out:
# <Axes: xlabel='continent'>

# %%
df3 = df2.transpose()

# %%
df3.plot()
# Out:
# <Axes: >

# %%
df3.boxplot()
# Out:
# <Axes: >

# %%
df.select_dtypes(include = 'float')
# Out:
#      2023 population  2022 population  2020 population  2015 population  \
# 0                NaN    1417173173.00    1396387127.00    1322866505.00
# 1      1425671352.00    1425887337.00    1424929781.00    1393715448.00
# 2       339996563.00     338289857.00     335942003.00     324607776.00
# 3       277534122.00     275501339.00     271857970.00     259091970.00
# 4       240485658.00     235824862.00     227196741.00     210969298.00
# 5       223804632.00     218541212.00     208327405.00     183995785.00
# 6       216422446.00     215313498.00     213196304.00     205188205.00
# 7       172954319.00     171186372.00     167420951.00     157830000.00
# 8       144444359.00     144713314.00     145617329.00     144668389.00
# 9       128455567.00     127504125.00     125998302.00     120149897.00
# 10      126527060.00     123379924.00     117190911.00     102471895.00
# 11      123294513.00     123951692.00     125244761.00     127250933.00
# ...
