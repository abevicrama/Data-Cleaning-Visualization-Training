# %% [markdown]
# Pandas training 02

# %%
import pandas as pd

# %%
df = pd.read_csv('country-codes.csv', index_col = "CLDR display name")

# %%
df.info
# Out:
# <bound method DataFrame.info of     FIFA   Dial ISO3166-1-Alpha-3 MARC   is_independent  ISO3166-1-numeric  \
# 0    AFG     93               AFG   af              Yes                  4
# 1    ALD    358               ALA            Part of FI                248
# 2    ALB    355               ALB   aa              Yes                  8
# 3    ALG    213               DZA   ae              Yes                 12
# 4    ASA  1-684               ASM   as  Territory of US                 16
# ..   ...    ...               ...  ...              ...                ...
# 244  WLF    681               WLF   wf  Territory of FR                876
# 245  SAH    212               ESH   ss    In contention                732
# 246  YEM    967               YEM   ye              Yes                887
# 247  ZAM    260               ZMB   za              Yes                894
# 248  ZIM    263               ZWE   rh              Yes                716
#
# ...

# %%
df.head()
# Out:
#                   FIFA   Dial ISO3166-1-Alpha-3 MARC   is_independent  \
# CLDR display name
# Afghanistan        AFG     93               AFG   af              Yes
# Kepulauan Aland    ALD    358               ALA            Part of FI
# Albania            ALB    355               ALB   aa              Yes
# Algeria            ALG    213               DZA   ae              Yes
# Samoa Amerika      ASA  1-684               ASM   as  Territory of US
#
#                    ISO3166-1-numeric    GAUL FIPS WMO ISO3166-1-Alpha-2  ...  \
# CLDR display name                                                        ...
# Afghanistan                        4     1.0   AF  AF                AF  ...
# Kepulauan Aland                  248  1242.0                         AX  ...
# Albania                            8     3.0   AL  AB                AL  ...
# Algeria                           12     4.0   AG  AL                DZ  ...
# ...

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#      CLDR display name FIFA   Dial ISO3166-1-Alpha-3 MARC   is_independent  \
# 0          Afghanistan  AFG     93               AFG   af              Yes
# 1      Kepulauan Aland  ALD    358               ALA            Part of FI
# 2              Albania  ALB    355               ALB   aa              Yes
# 3              Algeria  ALG    213               DZA   ae              Yes
# 4        Samoa Amerika  ASA  1-684               ASM   as  Territory of US
# ..                 ...  ...    ...               ...  ...              ...
# 244  Wallis dan Futuna  WLF    681               WLF   wf  Territory of FR
# 245       Sahara Barat  SAH    212               ESH   ss    In contention
# 246              Yaman  YEM    967               YEM   ye              Yes
# 247             Zambia  ZAM    260               ZMB   za              Yes
# 248           Zimbabwe  ZIM    263               ZWE   rh              Yes
#
#      ISO3166-1-numeric    GAUL FIPS WMO  ...     Sub-region Name  \
# ...

# %%
df2 = df.set_index('CLDR display name')
df2
# Out:
#                   FIFA   Dial ISO3166-1-Alpha-3 MARC   is_independent  \
# CLDR display name
# Afghanistan        AFG     93               AFG   af              Yes
# Kepulauan Aland    ALD    358               ALA            Part of FI
# Albania            ALB    355               ALB   aa              Yes
# Algeria            ALG    213               DZA   ae              Yes
# Samoa Amerika      ASA  1-684               ASM   as  Territory of US
# ...                ...    ...               ...  ...              ...
# Wallis dan Futuna  WLF    681               WLF   wf  Territory of FR
# Sahara Barat       SAH    212               ESH   ss    In contention
# Yaman              YEM    967               YEM   ye              Yes
# Zambia             ZAM    260               ZMB   za              Yes
# Zimbabwe           ZIM    263               ZWE   rh              Yes
#
#                    ISO3166-1-numeric    GAUL FIPS WMO ISO3166-1-Alpha-2  ...  \
# ...

# %%
df2.loc['Yaman']
# Out:
# FIFA                                                                      YEM
# Dial                                                                      967
# ISO3166-1-Alpha-3                                                         YEM
# MARC                                                                       ye
# is_independent                                                            Yes
# ISO3166-1-numeric                                                         887
# GAUL                                                                    269.0
# FIPS                                                                       YM
# WMO                                                                        YE
# ISO3166-1-Alpha-2                                                          YE
# ITU                                                                       YEM
# IOC                                                                       YEM
# ...

# %%
print(df2.index)
# Out:
# Index(['Afghanistan', 'Kepulauan Aland', 'Albania', 'Algeria', 'Samoa Amerika',
#        'Andorra', 'Angola', 'Anguilla', 'Antartika', 'Antigua dan Barbuda',
#        ...
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'Wallis dan Futuna', 'Sahara Barat', 'Yaman', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='CLDR display name', length=249)

# %%
pd.describe_option('display.max_rows')
# Out:
# display.max_rows : int
#     If max_rows is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the height of the terminal and print a truncated object which fits
#     the screen height. The IPython notebook, IPython qtconsole, or
#     IDLE do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 60] [currently: 60]

# %%
df2.sort_index()
# Out:
#                              FIFA Dial ISO3166-1-Alpha-3 MARC  \
# CLDR display name
# A.S                           USA    1               USA  xxu
# Afghanistan                   AFG   93               AFG   af
# Afrika Selatan                RSA   27               ZAF   sa
# Albania                       ALB  355               ALB   aa
# Algeria                       ALG  213               DZA   ae
# ...                           ...  ...               ...  ...
# Wilayah Lautan Hindi British  NaN  246               IOT   bi
# Wilayah Selatan Perancis      NaN  262               ATF   fs
# Yaman                         YEM  967               YEM   ye
# Zambia                        ZAM  260               ZMB   za
# Zimbabwe                      ZIM  263               ZWE   rh
#
#                                is_independent  ISO3166-1-numeric   GAUL FIPS  \
# CLDR display name
# A.S                                       Yes                840  259.0   US
# ...

# %%
df2 = df.set_index(['CLDR display name','Capital'])
df2
# Out:
#                             FIFA   Dial ISO3166-1-Alpha-3 MARC  \
# CLDR display name Capital
# Afghanistan       Kabul      AFG     93               AFG   af
# Kepulauan Aland   Mariehamn  ALD    358               ALA
# Albania           Tirana     ALB    355               ALB   aa
# Algeria           Algiers    ALG    213               DZA   ae
# Samoa Amerika     Pago Pago  ASA  1-684               ASM   as
# ...                          ...    ...               ...  ...
# Wallis dan Futuna Mata Utu   WLF    681               WLF   wf
# Sahara Barat      El-Aaiun   SAH    212               ESH   ss
# Yaman             Sanaa      YEM    967               YEM   ye
# Zambia            Lusaka     ZAM    260               ZMB   za
# Zimbabwe          Harare     ZIM    263               ZWE   rh
#
#                               is_independent  ISO3166-1-numeric    GAUL FIPS  \
# CLDR display name Capital
# Afghanistan       Kabul                  Yes                  4     1.0   AF
# ...

# %%
df2.head(20)
# Out:
#                                       FIFA   Dial ISO3166-1-Alpha-3 MARC  \
# CLDR display name   Capital
# Afghanistan         Kabul              AFG     93               AFG   af
# Kepulauan Aland     Mariehamn          ALD    358               ALA
# Albania             Tirana             ALB    355               ALB   aa
# Algeria             Algiers            ALG    213               DZA   ae
# Samoa Amerika       Pago Pago          ASA  1-684               ASM   as
# Andorra             Andorra la Vella   AND    376               AND   an
# Angola              Luanda             ANG    244               AGO   ao
# Anguilla            The Valley         AIA  1-264               AIA   am
# Antartika           NaN               ROS3    672               ATA   ay
# Antigua dan Barbuda St. John's         ATG  1-268               ATG   aq
# Argentina           Buenos Aires       ARG     54               ARG   ag
# ...
