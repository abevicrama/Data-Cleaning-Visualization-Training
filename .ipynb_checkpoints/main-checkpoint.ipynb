# %% [markdown]
# Pandas Trainin 01

# %%
# !pip install pandas

# %%
import pandas

# %%
file = pandas.read_csv(r'country-codes.csv', sep = ',')

# %%
pandas.set_option('display.max_row',100)

# %%
file.head(100)
# Out:
#   FIFA   Dial ISO3166-1-Alpha-3 MARC   is_independent  ISO3166-1-numeric  \
# 0  AFG     93               AFG   af              Yes                  4
# 1  ALD    358               ALA            Part of FI                248
# 2  ALB    355               ALB   aa              Yes                  8
# 3  ALG    213               DZA   ae              Yes                 12
# 4  ASA  1-684               ASM   as  Territory of US                 16
#
#      GAUL FIPS WMO ISO3166-1-Alpha-2  ...    official_name_ru Global Name  \
# 0     1.0   AF  AF                AF  ...          Афганистан       World
# 1  1242.0                         AX  ...  Аландских островов       World
# 2     3.0   AL  AB                AL  ...             Албания       World
# 3     4.0   AG  AL                DZ  ...               Алжир       World
# 4     5.0   AQ                    AS  ...  Американское Самоа       World
#
#      Capital Continent  TLD          Languages Geoname ID CLDR display name  \
# ...

# %%
file.describe()
# Out:
#        ISO3166-1-numeric          GAUL  Global Code  Intermediate Region Code  \
# count         249.000000    243.000000        249.0                105.000000
# mean          433.835341   1011.864198          1.0                 16.514286
# std           252.980446   7198.425819          0.0                  8.351778
# min             4.000000      1.000000          1.0                  5.000000
# 25%           218.000000     70.500000          1.0                 11.000000
# 50%           434.000000    145.000000          1.0                 14.000000
# 75%           652.000000    210.500000          1.0                 29.000000
# max           894.000000  91267.000000          1.0                 29.000000
#
#               M49  Sub-region Code  Region Code    Geoname ID
# count  249.000000       248.000000   248.000000  2.490000e+02
# mean   433.835341       179.866935    65.951613  2.385470e+06
# std    252.980446       138.334170    67.347832  1.544676e+06
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 56 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   FIFA                                     239 non-null    object
#  1   Dial                                     249 non-null    object
#  2   ISO3166-1-Alpha-3                        249 non-null    object
#  3   MARC                                     249 non-null    object
#  4   is_independent                           249 non-null    object
#  5   ISO3166-1-numeric                        249 non-null    int64
#  6   GAUL                                     243 non-null    float64
#  7   FIPS                                     249 non-null    object
#  8   WMO                                      246 non-null    object
#  9   ISO3166-1-Alpha-2                        248 non-null    object
# ...

# %%
file.shape
# Out:
# (249, 56)

# %%
file.loc[200]
# Out:
# FIFA                                                                      SIN
# Dial                                                                       65
# ISO3166-1-Alpha-3                                                         SGP
# MARC                                                                       si
# is_independent                                                            Yes
# ISO3166-1-numeric                                                         702
# GAUL                                                                    222.0
# FIPS                                                                       SN
# WMO                                                                        SR
# ISO3166-1-Alpha-2                                                          SG
# ITU                                                                       SNG
# IOC                                                                       SIN
# ...

# %%
file.iloc[200]
# Out:
# FIFA                                                                      SIN
# Dial                                                                       65
# ISO3166-1-Alpha-3                                                         SGP
# MARC                                                                       si
# is_independent                                                            Yes
# ISO3166-1-numeric                                                         702
# GAUL                                                                    222.0
# FIPS                                                                       SN
# WMO                                                                        SR
# ISO3166-1-Alpha-2                                                          SG
# ITU                                                                       SNG
# IOC                                                                       SIN
# ...

# %%
file.iloc[65]
# Out:
# FIFA                                                                      DMA
# Dial                                                                    1-767
# ISO3166-1-Alpha-3                                                         DMA
# MARC                                                                       dq
# is_independent                                                            Yes
# ISO3166-1-numeric                                                         212
# GAUL                                                                     71.0
# FIPS                                                                       DO
# WMO                                                                        DO
# ISO3166-1-Alpha-2                                                          DM
# ITU                                                                       DMA
# IOC                                                                       DMA
# ...

# %%
sC = ['Algeria','Sri Lanka']

# %%
file[file['CLDR display name'].isin(sC)]
# Out:
#     FIFA Dial ISO3166-1-Alpha-3 MARC is_independent  ISO3166-1-numeric   GAUL  \
# 3    ALG  213               DZA   ae            Yes                 12    4.0
# 210  SRI   94               LKA   ce            Yes                144  231.0
#
#     FIPS WMO ISO3166-1-Alpha-2  ... official_name_ru Global Name  Capital  \
# 3     AG  AL                DZ  ...            Алжир       World  Algiers
# 210   CE  SB                LK  ...        Шри-Ланка       World  Colombo
#
#     Continent  TLD  Languages Geoname ID CLDR display name EDGAR  \
# 3          AF  .dz      ar-DZ    2589581           Algeria    B4
# 210        AS  .lk   si,ta,en    1227603         Sri Lanka    F1
#
#                             wikidata_id
# 3    https://www.wikidata.org/wiki/Q262
# 210  https://www.wikidata.org/wiki/Q854
#
# [2 rows x 56 columns]

# %%
file[file['Dial'].str.contains('94')]
# Out:
#     FIFA Dial ISO3166-1-Alpha-3 MARC is_independent  ISO3166-1-numeric   GAUL  \
# 15   AZE  994               AZE   aj            Yes                 31   19.0
# 80   GUF  594               GUF   fg     Part of FR                254   86.0
# 210  SRI   94               LKA   ce            Yes                144  231.0
#
#     FIPS WMO ISO3166-1-Alpha-2  ...    official_name_ru Global Name  Capital  \
# 15    AJ  AJ                AZ  ...         Азербайджан       World     Baku
# 80    FG  FG                GF  ...  Французская Гвиана       World  Cayenne
# 210   CE  SB                LK  ...           Шри-Ланка       World  Colombo
#
#     Continent  TLD  Languages Geoname ID CLDR display name EDGAR  \
# 15         AS  .az   az,ru,hy     587116        Azerbaijan    1D
# 80         SA  .gf      fr-GF    3381670   Guiana Perancis    I3
# 210        AS  .lk   si,ta,en    1227603         Sri Lanka    F1
#
#                              wikidata_id
# ...

# %%
file.set_index('FIFA')
# Out:
#        Dial ISO3166-1-Alpha-3 MARC   is_independent  ISO3166-1-numeric  \
# FIFA
# AFG      93               AFG   af              Yes                  4
# ALD     358               ALA            Part of FI                248
# ALB     355               ALB   aa              Yes                  8
# ALG     213               DZA   ae              Yes                 12
# ASA   1-684               ASM   as  Territory of US                 16
# ...     ...               ...  ...              ...                ...
# WLF     681               WLF   wf  Territory of FR                876
# SAH     212               ESH   ss    In contention                732
# YEM     967               YEM   ye              Yes                887
# ZAM     260               ZMB   za              Yes                894
# ZIM     263               ZWE   rh              Yes                716
#
#         GAUL FIPS WMO ISO3166-1-Alpha-2  ITU  ...         official_name_ru  \
# ...

# %%
file.filter(items = ['CLDR display name','Dial'])
# Out:
#      CLDR display name   Dial
# 0          Afghanistan     93
# 1      Kepulauan Aland    358
# 2              Albania    355
# 3              Algeria    213
# 4        Samoa Amerika  1-684
# ..                 ...    ...
# 244  Wallis dan Futuna    681
# 245       Sahara Barat    212
# 246              Yaman    967
# 247             Zambia    260
# 248           Zimbabwe    263
#
# [249 rows x 2 columns]

# %%
file.set_index('CLDR display name')
# Out:
#                   FIFA   Dial ISO3166-1-Alpha-3 MARC   is_independent  \
# CLDR display name
# Afghanistan        AFG     93               AFG   af              Yes
# Kepulauan Aland    ALD    358               ALA            Part of FI
# Albania            ALB    355               ALB   aa              Yes
# Algeria            ALG    213               DZA   ae              Yes
# Samoa Amerika      ASA  1-684               ASM   as  Territory of US
# ...                ...    ...               ...  ...              ...
# Wallis dan Futuna  WLF    681               WLF   wf  Territory of FR
# Sahara Barat       SAH    212               ESH   ss    In contention
# Yaman              YEM    967               YEM   ye              Yes
# Zambia             ZAM    260               ZMB   za              Yes
# Zimbabwe           ZIM    263               ZWE   rh              Yes
#
#                    ISO3166-1-numeric    GAUL FIPS WMO ISO3166-1-Alpha-2  ...  \
# ...

# %%
file.iloc[3]
# Out:
# FIFA                                                                                     ALG
# Dial                                                                                     213
# ISO3166-1-Alpha-3                                                                        DZA
# MARC                                                                                      ae
# is_independent                                                                           Yes
# ISO3166-1-numeric                                                                         12
# GAUL                                                                                     4.0
# FIPS                                                                                      AG
# WMO                                                                                       AL
# ISO3166-1-Alpha-2                                                                         DZ
# ...

# %%
file[file['GAUL']< 100.0].sort_values(by=['FIFA'], ascending = True)
# Out:
#      FIFA               Dial ISO3166-1-Alpha-3 MARC      is_independent  \
# 0     AFG                 93               AFG   af                 Yes
# 7     AIA              1-264               AIA   am     Territory of GB
# 2     ALB                355               ALB   aa                 Yes
# 3     ALG                213               DZA   ae                 Yes
# 5     AND                376               AND   an                 Yes
# 6     ANG                244               AGO   ao                 Yes
# 10    ARG                 54               ARG   ag                 Yes
# 11    ARM                374               ARM   ai                 Yes
# 12    ARU                297               ABW   aw          Part of NL
# 4     ASA              1-684               ASM   as     Territory of US
# 9     ATG              1-268               ATG   aq                 Yes
# 13    AUS                 61               AUS   at                 Yes
# ...

# %%
file[file['GAUL']< 100.0].sort_values(by=['FIFA'], ascending = False)
# Out:
#      FIFA               Dial ISO3166-1-Alpha-3 MARC      is_independent  \
# 33    VGB              1-284               VGB   vb     Territory of GB
# 81   TAH2                689               PYF   fp     Territory of FR
# 69    SLV                503               SLV   es                 Yes
# 8    ROS3                672               ATA   ay       International
# 61    PRK                850               PRK   kn                 Yes
# 80    GUF                594               GUF   fg          Part of FR
# 91    GRN              1-473               GRD   gd                 Yes
# 90    GRL                299               GRL   gl          Part of DK
# 89    GRE                 30               GRC   gr                 Yes
# 87    GHA                233               GHA   gh                 Yes
# 86    GER                 49               DEU   gw                 Yes
# 85    GEO                995               GEO   gs                 Yes
# ...
